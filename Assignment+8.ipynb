# %% [markdown]
# ## IS362 Assignment 8
#
# Your task in this week’s assignment is to load a dataset, perform some minor cleanup and transformation tasks, then use exploratory data analysis to learn about the distribution of variables and the relationship between variables.
# Here is a link to the “Auto MPG” dataset in the UC Irvine data repository: https://archive.ics.uci.edu/ml/datasets/Auto+MPG.
#
# 1. Load the data in the (yellow highlighted) Data Folder in the file auto-mpg.data into a pandas DataFrame.
#
# 2. Review the data and the provided data set description.
#
# 3. Use the attribute information provided in auto-mpg.names to name your pandas DataFrame columns.
#
# 4. Some of the horsepower data is marked as missing with a ‘?’. You need to replace this ‘?’ with a pandas-appropriate missing value, then convert the column to numeric.
#
# 5. The origin column values are 1, 2, and 3. Convert these values respectively to ‘USA’, ‘Asia’, and ‘Europe’
#
# 6. Create a bar chart that shows the distribution for cylinders.
#
# 7. Create a scatterplot that shows the relationship between horsepower and weight.
#
# 8. Ask, then answer (using matplotlib and seaborn graphics capabilities) an interesting question about the distribution of one of the variables, or the relationship between two (or more!) of the variables in the “Auto MPG” dataset.

# %%
#The code below imports pandas, numpy, matplot & seaborn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#the code below retrieves the dataset & loads it into a table
uc_header = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model', 'origin', 'car name']
uc_data = pd.read_fwf('https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data', uc_header= None, names=uc_header)
cols = uc_data.columns.tolist()
cols = cols[-1:] + cols[:-1]
uc_data = uc_data[cols]
uc_data
# Out:
#                                car name   mpg  cylinders  displacement  \
# 0           "chevrolet chevelle malibu"  18.0          8         307.0
# 1                   "buick skylark 320"  15.0          8         350.0
# 2                  "plymouth satellite"  18.0          8         318.0
# 3                       "amc rebel sst"  16.0          8         304.0
# 4                         "ford torino"  17.0          8         302.0
# 5                    "ford galaxie 500"  15.0          8         429.0
# 6                    "chevrolet impala"  14.0          8         454.0
# 7                   "plymouth fury iii"  14.0          8         440.0
# 8                    "pontiac catalina"  14.0          8         455.0
# 9                  "amc ambassador dpl"  15.0          8         390.0
# 10                "dodge challenger se"  15.0          8         383.0
# 11                 "plymouth 'cuda 340"  14.0          8         340.0
# 12              "chevrolet monte carlo"  15.0          8         400.0
# 13            "buick estate wagon (sw)"  14.0          8         455.0
# 14              "toyota corona mark ii"  24.0          4         113.0
# 15                    "plymouth duster"  22.0          6         198.0
# 16                         "amc hornet"  18.0          6         199.0
# 17                      "ford maverick"  21.0          6         200.0
# 18                       "datsun pl510"  27.0          4          97.0
# 19       "volkswagen 1131 deluxe sedan"  26.0          4          97.0
# 20                        "peugeot 504"  25.0          4         110.0
# 21                        "audi 100 ls"  24.0          4         107.0
# 22                           "saab 99e"  25.0          4         104.0
# 23                           "bmw 2002"  26.0          4         121.0
# 24                        "amc gremlin"  21.0          6         199.0
# 25                          "ford f250"  10.0          8         360.0
# 26                          "chevy c20"  10.0          8         307.0
# 27                         "dodge d200"  11.0          8         318.0
# 28                           "hi 1200d"   9.0          8         304.0
# 29                       "datsun pl510"  27.0          4          97.0
# ..                                  ...   ...        ...           ...
# 368          "chevrolet cavalier wagon"  27.0          4         112.0
# 369         "chevrolet cavalier 2-door"  34.0          4         112.0
# 370        "pontiac j2000 se hatchback"  31.0          4         112.0
# 371                    "dodge aries se"  29.0          4         135.0
# 372                   "pontiac phoenix"  27.0          4         151.0
# 373              "ford fairmont futura"  24.0          4         140.0
# 374                    "amc concord dl"  23.0          4         151.0
# 375               "volkswagen rabbit l"  36.0          4         105.0
# 376                "mazda glc custom l"  37.0          4          91.0
# 377                  "mazda glc custom"  31.0          4          91.0
# 378            "plymouth horizon miser"  38.0          4         105.0
# 379                    "mercury lynx l"  36.0          4          98.0
# 380                  "nissan stanza xe"  36.0          4         120.0
# 381                      "honda accord"  36.0          4         107.0
# 382                    "toyota corolla"  34.0          4         108.0
# 383                       "honda civic"  38.0          4          91.0
# 384                "honda civic (auto)"  32.0          4          91.0
# 385                     "datsun 310 gx"  38.0          4          91.0
# 386             "buick century limited"  25.0          6         181.0
# 387  "oldsmobile cutlass ciera (diesel)  38.0          6         262.0
# 388        "chrysler lebaron medallion"  26.0          4         156.0
# 389                    "ford granada l"  22.0          6         232.0
# 390                  "toyota celica gt"  32.0          4         144.0
# 391                 "dodge charger 2.2"  36.0          4         135.0
# 392                  "chevrolet camaro"  27.0          4         151.0
# 393                   "ford mustang gl"  27.0          4         140.0
# 394                         "vw pickup"  44.0          4          97.0
# 395                     "dodge rampage"  32.0          4         135.0
# 396                       "ford ranger"  28.0          4         120.0
# 397                        "chevy s-10"  31.0          4         119.0
#
#     horsepower  weight  acceleration  model  origin
# 0        130.0  3504.0          12.0     70       1
# 1        165.0  3693.0          11.5     70       1
# 2        150.0  3436.0          11.0     70       1
# 3        150.0  3433.0          12.0     70       1
# 4        140.0  3449.0          10.5     70       1
# 5        198.0  4341.0          10.0     70       1
# 6        220.0  4354.0           9.0     70       1
# 7        215.0  4312.0           8.5     70       1
# 8        225.0  4425.0          10.0     70       1
# 9        190.0  3850.0           8.5     70       1
# 10       170.0  3563.0          10.0     70       1
# 11       160.0  3609.0           8.0     70       1
# 12       150.0  3761.0           9.5     70       1
# 13       225.0  3086.0          10.0     70       1
# 14       95.00  2372.0          15.0     70       3
# 15       95.00  2833.0          15.5     70       1
# 16       97.00  2774.0          15.5     70       1
# 17       85.00  2587.0          16.0     70       1
# 18       88.00  2130.0          14.5     70       3
# 19       46.00  1835.0          20.5     70       2
# 20       87.00  2672.0          17.5     70       2
# 21       90.00  2430.0          14.5     70       2
# 22       95.00  2375.0          17.5     70       2
# 23       113.0  2234.0          12.5     70       2
# 24       90.00  2648.0          15.0     70       1
# 25       215.0  4615.0          14.0     70       1
# 26       200.0  4376.0          15.0     70       1
# 27       210.0  4382.0          13.5     70       1
# 28       193.0  4732.0          18.5     70       1
# 29       88.00  2130.0          14.5     71       3
# ..         ...     ...           ...    ...     ...
# 368      88.00  2640.0          18.6     82       1
# 369      88.00  2395.0          18.0     82       1
# 370      85.00  2575.0          16.2     82       1
# 371      84.00  2525.0          16.0     82       1
# 372      90.00  2735.0          18.0     82       1
# 373      92.00  2865.0          16.4     82       1
# 374          ?  3035.0          20.5     82       1
# 375      74.00  1980.0          15.3     82       2
# 376      68.00  2025.0          18.2     82       3
# 377      68.00  1970.0          17.6     82       3
# 378      63.00  2125.0          14.7     82       1
# 379      70.00  2125.0          17.3     82       1
# 380      88.00  2160.0          14.5     82       3
# 381      75.00  2205.0          14.5     82       3
# 382      70.00  2245.0          16.9     82       3
# 383      67.00  1965.0          15.0     82       3
# 384      67.00  1965.0          15.7     82       3
# 385      67.00  1995.0          16.2     82       3
# 386      110.0  2945.0          16.4     82       1
# 387      85.00  3015.0          17.0     82       1
# 388      92.00  2585.0          14.5     82       1
# 389      112.0  2835.0          14.7     82       1
# 390      96.00  2665.0          13.9     82       3
# 391      84.00  2370.0          13.0     82       1
# 392      90.00  2950.0          17.3     82       1
# 393      86.00  2790.0          15.6     82       1
# 394      52.00  2130.0          24.6     82       2
# 395      84.00  2295.0          11.6     82       1
# 396      79.00  2625.0          18.6     82       1
# 397      82.00  2720.0          19.4     82       1
#
# [398 rows x 9 columns]

# %%
#The code below updates the dataset to address missing values and updates the origin column (1=USA, 2=ASIA, 3=EUROPE)
uc_data = uc_data.replace(to_replace='?', value=np.nan)
uc_data['horsepower'] = uc_data['horsepower'].astype(float)
uc_data['origin'].replace(1, 'USA', inplace=True)
uc_data['origin'].replace(2, 'Asia', inplace=True)
uc_data['origin'].replace(3, 'Europe', inplace=True)
uc_data
# Out:
#                                car name   mpg  cylinders  displacement  \
# 0           "chevrolet chevelle malibu"  18.0          8         307.0
# 1                   "buick skylark 320"  15.0          8         350.0
# 2                  "plymouth satellite"  18.0          8         318.0
# 3                       "amc rebel sst"  16.0          8         304.0
# 4                         "ford torino"  17.0          8         302.0
# 5                    "ford galaxie 500"  15.0          8         429.0
# 6                    "chevrolet impala"  14.0          8         454.0
# 7                   "plymouth fury iii"  14.0          8         440.0
# 8                    "pontiac catalina"  14.0          8         455.0
# 9                  "amc ambassador dpl"  15.0          8         390.0
# 10                "dodge challenger se"  15.0          8         383.0
# 11                 "plymouth 'cuda 340"  14.0          8         340.0
# 12              "chevrolet monte carlo"  15.0          8         400.0
# 13            "buick estate wagon (sw)"  14.0          8         455.0
# 14              "toyota corona mark ii"  24.0          4         113.0
# 15                    "plymouth duster"  22.0          6         198.0
# 16                         "amc hornet"  18.0          6         199.0
# 17                      "ford maverick"  21.0          6         200.0
# 18                       "datsun pl510"  27.0          4          97.0
# 19       "volkswagen 1131 deluxe sedan"  26.0          4          97.0
# 20                        "peugeot 504"  25.0          4         110.0
# 21                        "audi 100 ls"  24.0          4         107.0
# 22                           "saab 99e"  25.0          4         104.0
# 23                           "bmw 2002"  26.0          4         121.0
# 24                        "amc gremlin"  21.0          6         199.0
# 25                          "ford f250"  10.0          8         360.0
# 26                          "chevy c20"  10.0          8         307.0
# 27                         "dodge d200"  11.0          8         318.0
# 28                           "hi 1200d"   9.0          8         304.0
# 29                       "datsun pl510"  27.0          4          97.0
# ..                                  ...   ...        ...           ...
# 368          "chevrolet cavalier wagon"  27.0          4         112.0
# 369         "chevrolet cavalier 2-door"  34.0          4         112.0
# 370        "pontiac j2000 se hatchback"  31.0          4         112.0
# 371                    "dodge aries se"  29.0          4         135.0
# 372                   "pontiac phoenix"  27.0          4         151.0
# 373              "ford fairmont futura"  24.0          4         140.0
# 374                    "amc concord dl"  23.0          4         151.0
# 375               "volkswagen rabbit l"  36.0          4         105.0
# 376                "mazda glc custom l"  37.0          4          91.0
# 377                  "mazda glc custom"  31.0          4          91.0
# 378            "plymouth horizon miser"  38.0          4         105.0
# 379                    "mercury lynx l"  36.0          4          98.0
# 380                  "nissan stanza xe"  36.0          4         120.0
# 381                      "honda accord"  36.0          4         107.0
# 382                    "toyota corolla"  34.0          4         108.0
# 383                       "honda civic"  38.0          4          91.0
# 384                "honda civic (auto)"  32.0          4          91.0
# 385                     "datsun 310 gx"  38.0          4          91.0
# 386             "buick century limited"  25.0          6         181.0
# 387  "oldsmobile cutlass ciera (diesel)  38.0          6         262.0
# 388        "chrysler lebaron medallion"  26.0          4         156.0
# 389                    "ford granada l"  22.0          6         232.0
# 390                  "toyota celica gt"  32.0          4         144.0
# 391                 "dodge charger 2.2"  36.0          4         135.0
# 392                  "chevrolet camaro"  27.0          4         151.0
# 393                   "ford mustang gl"  27.0          4         140.0
# 394                         "vw pickup"  44.0          4          97.0
# 395                     "dodge rampage"  32.0          4         135.0
# 396                       "ford ranger"  28.0          4         120.0
# 397                        "chevy s-10"  31.0          4         119.0
#
#      horsepower  weight  acceleration  model  origin
# 0         130.0  3504.0          12.0     70     USA
# 1         165.0  3693.0          11.5     70     USA
# 2         150.0  3436.0          11.0     70     USA
# 3         150.0  3433.0          12.0     70     USA
# 4         140.0  3449.0          10.5     70     USA
# 5         198.0  4341.0          10.0     70     USA
# 6         220.0  4354.0           9.0     70     USA
# 7         215.0  4312.0           8.5     70     USA
# 8         225.0  4425.0          10.0     70     USA
# 9         190.0  3850.0           8.5     70     USA
# 10        170.0  3563.0          10.0     70     USA
# 11        160.0  3609.0           8.0     70     USA
# 12        150.0  3761.0           9.5     70     USA
# 13        225.0  3086.0          10.0     70     USA
# 14         95.0  2372.0          15.0     70  Europe
# 15         95.0  2833.0          15.5     70     USA
# 16         97.0  2774.0          15.5     70     USA
# 17         85.0  2587.0          16.0     70     USA
# 18         88.0  2130.0          14.5     70  Europe
# 19         46.0  1835.0          20.5     70    Asia
# 20         87.0  2672.0          17.5     70    Asia
# 21         90.0  2430.0          14.5     70    Asia
# 22         95.0  2375.0          17.5     70    Asia
# 23        113.0  2234.0          12.5     70    Asia
# 24         90.0  2648.0          15.0     70     USA
# 25        215.0  4615.0          14.0     70     USA
# 26        200.0  4376.0          15.0     70     USA
# 27        210.0  4382.0          13.5     70     USA
# 28        193.0  4732.0          18.5     70     USA
# 29         88.0  2130.0          14.5     71  Europe
# ..          ...     ...           ...    ...     ...
# 368        88.0  2640.0          18.6     82     USA
# 369        88.0  2395.0          18.0     82     USA
# 370        85.0  2575.0          16.2     82     USA
# 371        84.0  2525.0          16.0     82     USA
# 372        90.0  2735.0          18.0     82     USA
# 373        92.0  2865.0          16.4     82     USA
# 374         NaN  3035.0          20.5     82     USA
# 375        74.0  1980.0          15.3     82    Asia
# 376        68.0  2025.0          18.2     82  Europe
# 377        68.0  1970.0          17.6     82  Europe
# 378        63.0  2125.0          14.7     82     USA
# 379        70.0  2125.0          17.3     82     USA
# 380        88.0  2160.0          14.5     82  Europe
# 381        75.0  2205.0          14.5     82  Europe
# 382        70.0  2245.0          16.9     82  Europe
# 383        67.0  1965.0          15.0     82  Europe
# 384        67.0  1965.0          15.7     82  Europe
# 385        67.0  1995.0          16.2     82  Europe
# 386       110.0  2945.0          16.4     82     USA
# 387        85.0  3015.0          17.0     82     USA
# 388        92.0  2585.0          14.5     82     USA
# 389       112.0  2835.0          14.7     82     USA
# 390        96.0  2665.0          13.9     82  Europe
# 391        84.0  2370.0          13.0     82     USA
# 392        90.0  2950.0          17.3     82     USA
# 393        86.0  2790.0          15.6     82     USA
# 394        52.0  2130.0          24.6     82    Asia
# 395        84.0  2295.0          11.6     82     USA
# 396        79.0  2625.0          18.6     82     USA
# 397        82.0  2720.0          19.4     82     USA
#
# [398 rows x 9 columns]

# %%
#the code below creates a bar chart to show the distribution of cylinders
uc_data['cylinders'].plot(kind='bar', title='Distribution of Cylinders')
uc_data.groupby('cylinders')

# %%
#The code below will display a scatterplot showing the relationship between horsepower & weight
plt.scatter(uc_data['horsepower'], uc_data['weight'])
plt.suptitle('Horsepower & Weight')
plt.show()

# %% [markdown]
# ** Lets beautify our data using seaborn **

# %%
#the code below will display a scatterplot showing the relationship between horsepower & acceleration
sns.set(style="ticks", context="talk")
acchorse = uc_data[['horsepower', 'acceleration', 'origin']]
pal = sns.cubehelix_palette(4, 1.5, .75, light=.6, dark=.2)
g = sns.lmplot(x='horsepower', y='acceleration', hue='origin', data=acchorse, palette=pal, size=7)
g.set_axis_labels("Horsepower", "Acceleration")
sns.plt.show()

# %%
#The code below will display the a scatterplot showing the relationship between horespower & mpg
plt.scatter(uc_data['horsepower'], uc_data['mpg'])
plt.title('Horsepower to Miles Per Gallon')
plt.xlabel('Horsepower')
plt.ylabel('MPG')
plt.show()

# %%
#Finally, the code below will display a scatterplot showing the relationship between horsepower & weight
sns.set(style="ticks", context="talk")
acchorse = uc_data[['weight', 'horsepower', 'origin']]
pal = sns.cubehelix_palette(4, 1.5, .75, light=.6, dark=.2)
g = sns.lmplot(x='weight', y='horsepower', hue='origin', data=acchorse, palette=pal, size=7)
g.set_axis_labels("Weight", "Horsepower")
sns.plt.show()
